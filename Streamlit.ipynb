# %% [markdown]
# 1. Install Streamlit

# %%
pip install streamlit

# %%
# Map
pip install pydeck
# Out:
# ...
#    ---------------------------------------- 0.0/6.9 MB ? eta -:--:--
#    ---------- ----------------------------- 1.8/6.9 MB 8.8 MB/s eta 0:00:01
#    ------------------- -------------------- 3.4/6.9 MB 8.8 MB/s eta 0:00:01
#    ------------------------------ --------- 5.2/6.9 MB 8.6 MB/s eta 0:00:01
#    ---------------------------------------- 6.9/6.9 MB 8.5 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# 2. Open default page
#    * Terminal >> streamlit hello
