# %% [raw]
# 1. Install Library

# %%
pip install oracledb
# Out:
# Collecting oracledb
#   Downloading oracledb-3.4.0-cp313-cp313-win_amd64.whl.metadata (7.9 kB)
# Requirement already satisfied: cryptography>=3.2.1 in c:\users\77100643\anaconda3\lib\site-packages (from oracledb) (44.0.1)
# Collecting typing_extensions>=4.14.0 (from oracledb)
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: cffi>=1.12 in c:\users\77100643\anaconda3\lib\site-packages (from cryptography>=3.2.1->oracledb) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\77100643\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=3.2.1->oracledb) (2.21)
# Downloading oracledb-3.4.0-cp313-cp313-win_amd64.whl (1.9 MB)
#    ---------------------------------------- 0.0/1.9 MB ? eta -:--:--
#    ---------------------------- ----------- 1.3/1.9 MB 6.9 MB/s eta 0:00:01
#    ---------------------------------------- 1.9/1.9 MB 6.6 MB/s eta 0:00:00
# Using cached typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Installing collected packages: typing_extensions, oracledb
#
#   Attempting uninstall: typing_extensions
#
#     Found existing installation: typing_extensions 4.12.2
#
#     Uninstalling typing_extensions-4.12.2:
#
#    ---------------------------------------- 0/2 [typing_extensions]
#    ---------------------------------------- 0/2 [typing_extensions]
#    ---------------------------------------- 0/2 [typing_extensions]
#    ---------------------------------------- 0/2 [typing_extensions]
#    ---------------------------------------- 0/2 [typing_extensions]
#    ---------------------------------------- 0/2 [typing_extensions]
#    ---------------------------------------- 0/2 [typing_extensions]
#    ---------------------------------------- 0/2 [typing_extensions]
#    ---------------------------------------- 0/2 [typing_extensions]
#    ---------------------------------------- 0/2 [typing_extensions]
#    ---------------------------------------- 0/2 [typing_extensions]
#    ---------------------------------------- 0/2 [typing_extensions]
#    ---------------------------------------- 0/2 [typing_extensions]
#    ---------------------------------------- 0/2 [typing_extensions]
#    ---------------------------------------- 0/2 [typing_extensions]
#    ---------------------------------------- 0/2 [typing_extensions]
#    ---------------------------------------- 0/2 [typing_extensions]
#       Successfully uninstalled typing_extensions-4.12.2
#    ---------------------------------------- 0/2 [typing_extensions]
#    ---------------------------------------- 0/2 [typing_extensions]
#    -------------------- ------------------- 1/2 [oracledb]
#    ---------------------------------------- 2/2 [oracledb]
#
# Successfully installed oracledb-3.4.0 typing_extensions-4.15.0
# Note: you may need to restart the kernel to use updated packages.

# %% [raw]
# 2. Create and setup table

# %%
import os
import sys
import oracledb

un = os.getenv("user", "TESTDB")
pw = os.getenv("password", "?renoma1")
cs = os.getenv("connstr", "localhost:1521/FREEPDB1")

# Connect to Oracle Database
with oracledb.connect(user=un, password=pw, dsn=cs) as connection:
    db_version = tuple(int(s) for s in connection.version.split("."))

    if db_version < (23, 4):
        sys.exit("This example requires Oracle Database 23.4 or higher.")

    print("\nConnection to Oracle Databse")

# Drop and create a table called MY_DATA

    print("Creating schema objects")

    with connection.cursor() as cursor:
        sql = [
            """DROP TABLE IF EXISTS my_data PURGE""",
            """CREATE TABLE IF NOT EXISTS my_data (
                    id   number primary key,
                    info varchar2(128),
                    v    vector)""",
        ]
        
        for s in sql:
            try:
                cursor.execute(s)
            except oracledb.DatabaseError as e:
                if e.args[0].code != 942:  #ignore ORA-942: table does not exist
                    raise

        #Insert 150 rows of sample data
        data_to_insert = [
            (1, "San Francisco is in California.", None), 
            (2, "San Jose is in California.", None), 
            (3, "Los Angeles is in California.", None), 
            (4, "Buffalo is in New York.", None), 
            (5, "Brooklyn is in New York.", None), 
            (6, "Queens is in New York.", None), 
            (7, "Harlem is in New York.", None), 
            (8, "The Bronx is in New York.", None), 
            (9, "Manhattan is in New York.", None), 
            (10, "Staten Island is in New York.", None), 
            (11, "Miami is in Florida.", None), 
            (12, "Tampa is in Florida.", None), 
            (13, "Orlando is in Florida.", None), 
            (14, "Dallas is in Texas.", None), 
            (15, "Houston is in Texas.", None), 
            (16, "Austin is in Texas.", None), 
            (17, "Phoenix is in Arizona.", None), 
            (18, "Las Vegas is in Nevada.", None), 
            (19, "Portland is in Oregon.", None), 
            (20, "New Orleans is in Louisiana.", None), 
            (21, "Atlanta is in Georgia.", None), 
            (22, "Chicago is in Illinois.", None), 
            (23, "Cleveland is in Ohio.", None), 
            (24, "Boston is in Massachusetts.", None), 
            (25, "Baltimore is in Maryland.", None), 
            (26, "Charlotte is in North Carolina.", None), 
            (27, "Raleigh is in North Carolina.", None), 
            (28, "Detroit is in Michigan.", None),  
 
            (100, "Ferraris are often red.", None), 
            (101, "Teslas are electric.", None), 
            (102, "Mini Coopers are small.", None), 
            (103, "Fiat 500 are small.", None), 
            (104, "Dodge Vipers are wide.", None), 
            (105, "Ford 150 are popular.", None), 
            (106, "Alfa Romeos are fun.", None), 
            (107, "Volvos are safe.", None), 
            (108, "Toyotas are reliable.", None), 
            (109, "Hondas are reliable.", None), 
            (110, "Porsches are fast and reliable.", None), 
            (111, "Nissan GTR are great.", None), 
            (112, "NISMO is awesome.", None), 
            (113, "Tesla Cybertrucks are big.", None), 
            (114, "Jeep Wranglers are fun.", None), 
            (115, "Lamborghinis are fast.", None), 
 
            (200, "Bananas are yellow.", None), 
            (201, "Kiwis are green inside.", None), 
            (202, "Kiwis are brown on the outside.", None), 
            (203, "Kiwis are birds.", None), 
            (204, "Kiwis taste good.", None), 
            (205, "Ripe strawberries are red.", None), 
            (206, "Apples can be green, yellow or red.", None),
            (207, "Ripe cherries are red.", None), 
            (208, "Pears can be green, yellow or brown.", None),
            (209, "Oranges are orange.", None), 
            (210, "Peaches can be yellow, orange or red.", None), 
            (211, "Peaches can be fuzzy.", None), 
            (212, "Grapes can be green, red or puple.", None),
            (213, "Watermelons are green on the outside.", None), 
            (214, "Watermelons are red on the inside.", None), 
            (215, "Blueberries are blue.", None), 
            (216, "Limes are green.", None), 
            (217, "Lemons are yellow.", None),
            (218, "Ripe tomatoes are red.", None), 
            (219, "Unripe tomatoes are green.", None), 
            (220, "Ripe raspberries are red.", None), 
            (221, "Mangoes can be yellow, gold, green or orange.", None),
 
            (300, "Tigers have stripes.", None), 
            (301, "Lions are big.", None), 
            (302, "Mice are small.", None), 
            (303, "Cats do not care.", None), 
            (304, "Dogs are loyal.", None), 
            (305, "Bears are hairy.", None), 
            (306, "Pandas are black and white.", None), 
            (307, "Zebras are black and white.", None), 
            (308, "Penguins can be black and white.", None), 
            (309, "Puffins can be black and white.", None), 
            (310, "Giraffes have long necks.", None), 
            (311, "Elephants have trunks.", None), 
            (312, "Horses have four legs.", None), 
            (313, "Birds can fly.", None), 
            (314, "Birds lay eggs.", None), 
            (315, "Fish can swim.", None), 
            (316, "Sharks have lots of teeth.", None), 
            (317, "Flies can fly.", None), 
            (318, "Snakes have fangs.", None), 
            (319, "Hyenas laugh.", None), 
            (320, "Crocodiles lurk.", None), 
            (321, "Spiders have eight legs.", None), 
            (322, "Wolves are hairy.", None), 
            (323, "Mountain Lions eat deer.", None), 
            (324, "Kangaroos can hop.", None), 
            (325, "Turtles have shells.", None), 
 
            (400, "Ibaraki is in Kanto.", None), 
            (401, "Tochigi is in Kanto.", None), 
            (402, "Gunma is in Kanto.", None), 
            (403, "Saitama is in Kanto.", None), 
            (404, "Chiba is in Kanto.", None), 
            (405, "Tokyo is in Kanto.", None), 
            (406, "Kanagawa is in Kanto.", None), 
 
            (500, "Eggs are egg shaped.", None), 
            (501, "Sydney is in Australia.", None),
            (502, "To be, or not to be, taht is the question.", None), 
            (503, "640K ought to be enough for anybody.", None), 
            (504, "Man overboard.", None), 
            (505, "The world is your oyster.", None), 
            (506, "One small step for Mankind.", None), 
            (507, "Bitcoin is a cryptocurrency.", None), 
            (508, "Saturn has rings.", None), 
            (509, "Antarctica is very cold.", None), 
            (510, "Wellington is the capital of New Zealand.", None), 
            (511, "The Amazon River is the largest river by discharge.", None),
 
            (600, "Catamarans have two hulls.", None), 
            (601, "Monohulls have a single hull.", None), 
            (602, "Foiling sailboats are fast.", None), 
            (603, "Cutters have two headsails.", None), 
            (604, "Yawls have two masts.", None), 
            (605, "Sloops have one mast.", None), 
            (606, "HMS Endeavour was a squared rigged ship.", None), 
            (607, "Auckland has hosted the Americas Cup race three times.", None),
            (608, "Joshua Slocum sailed the first solo circumnavigation of the world.", None),
 
            (900, "Oracle CloudWorld Las Vegas was on September 18–21, 2023", None), 
            (901, "Oracle CloudWorld Las Vegas was at The Venetian Convention and Expo Center", None), 
            (902, "Oracle CloudWorld Dubai was on 23 January 2024", None), 
            (903, "Oracle CloudWorld Dubai is at the Dubai World Trade Centre", None), 
            (904, "Oracle CloudWorld Mumbai was on 14 February 2024", None), 
            (905, "Oracle CloudWorld Mumbai is at the Jio World Convention Centre", None), 
            (906, "Oracle CloudWorld London was on 14 March 2024", None), 
            (907, "Oracle CloudWorld London is at the ExCeL London", None), 
            (908, "Oracle CloudWorld Milan was on 21 March 2024", None), 
            (909, "Oracle CloudWorld Milan is at the Milano Convention Centre", None), 
            (910, "Oracle CloudWorld Sao Paulo was on 4 April 2024", None), 
            (911, "Oracle CloudWorld Sao Paulo is at the World Trade Center São Paulo", None), 
            (912, "Oracle CloudWorld Singapore is on 16 April 2024", None), 
            (914, "Oracle CloudWorld Tokyo is on 18 April 2024", None), 
            (915, "Oracle CloudWorld Tokyo is at The Prince Park Tower Tokyo", None), 
            (916, "Oracle CloudWorld Mexico City is on 25 April 2024", None), 
            (917, "Oracle CloudWorld Mexico City is at the Centro Citibanamex", None), 
 
            (1000, "Mumbai is in India.", None), 
            (1001, "Mumbai is the capital city of the Indian state of Maharashtra.", None), 
            (1002, "Mumbai is the Indian state of Maharashtra.", None), 
            (1003, "Mumbai is on the west coast of India.", None), 
            (1004, "Mumbai is the de facto financial centre of India.", None), 
            (1005, "Mumbai has a population of about 12.5 million people.", None), 
            (1006, "Mumbai is hot with an average minimum temperature of 24 degrees celsius.", None), 
            (1007, "Common languages in Mumbai are Marathi, Hindi, Gujarati, Urdu, Bambaiya and English.", None), 
 
            (1100, "Dubai is in the United Arab Emirates.", None), 
            (1101, "The Burj Khalifa is in Dubai.", None), 
            (1102, "The Burj Khalifa is tallest building in the world.", None), 
            (1103, "Dubai is in the Persian Gulf.", None), 
            (1104, "The United Arab Emirates consists of seven emirates.", None), 
        ]

        connection.autocommit = True

        cursor.executemany(
            """INSERT INTO my_data (id, info, v)
               VALUES (:1, :2, :3)""",
            data_to_insert,
        )

print("Create table MY_DATA and Inserted sample data.")
print("-------------------------------------------------------------------\n")
# Out:
# Connection to Oracle Databse
# Creating schema objects
# Create table MY_DATA and Inserted sample data.
# -------------------------------------------------------------------

# %% [raw]
# 3. Vectorizing a table with Sentence Transformers embedding model

# %%
pip install sentence-transformers
# Out:
# Collecting sentence-transformersNote: you may need to restart the kernel to use updated packages.
#
#   Downloading sentence_transformers-5.1.2-py3-none-any.whl.metadata (16 kB)
# Collecting transformers<5.0.0,>=4.41.0 (from sentence-transformers)
#   Downloading transformers-4.57.1-py3-none-any.whl.metadata (43 kB)
# Requirement already satisfied
8 MB/s eta 0:00:03
#    ---------------------------------- ----- 94.6/109.3 MB 6.8 MB/s eta 0:00:03
#    ----------------------------------- ---- 96.2/109.3 MB 6.8 MB/s eta 0:00:02
#    ----------------------------------- ---- 98.0/109.3 MB 6.8 MB/s eta 0:00:02
#    ------------------------------------ --- 99.9/109.3 MB 6.9 MB/s eta 0:00:02
#    ------------------------------------- -- 101.7/109.3 MB 6.9 MB/s eta 0:00:02
#    ------------------------------------- -- 103.5/109.3 MB 6.9 MB/s eta 0:00:01
#    -------------------------------------- - 105.1/109.3 MB 6.9 MB/s eta 0:00:01
#    -------------------------------------- - 106.4/109.3 MB 6.9 MB/s eta 0:00:01
#    ---------------------------------------  108.3/109.3 MB 7.0 MB/s eta 0:00:01
#    ---------------------------------------  109.1/109.3 MB 7.0 MB/s eta 0:00:01
#    ---------------------------------------- 109.3/109.3 MB 6.9 MB/s eta 0:00:00
# Installing collected packages: safetensors, torch, huggingface-hub, tokenizers, transformers, sentence-transformers
#
#    ---------------------------------------- 0/6 [safetensors]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------ --------------------------------- 1/6 [torch]
#    ------------- -------------------------- 2/6 [huggingface-hub]
#    ------------- -------------------------- 2/6 [huggingface-hub]
#    ------------- -------------------------- 2/6 [huggingface-hub]
#    ------------- -------------------------- 2/6 [huggingface-hub]
#    ------------- -------------------------- 2/6 [huggingface-hub]
#    ------------- -------------------------- 2/6 [huggingface-hub]
#    ------------- -------------------------- 2/6 [huggingface-hub]
#    ------------- -------------------------- 2/6 [huggingface-hub]
#    ------------- -------------------------- 2/6 [huggingface-hub]
#    ------------- -------------------------- 2/6 [huggingface-hub]
#    -------------------- ------------------- 3/6 [tokenizers]
#    -------------------- ------------------- 3/6 [tokenizers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    -------------------------- ------------- 4/6 [transformers]
#    --------------------------------- ------ 5/6 [sentence-transformers]
#    --------------------------------- ------ 5/6 [sentence-transformers]
#    --------------------------------- ------ 5/6 [sentence-transformers]
#    --------------------------------- ------ 5/6 [sentence-transformers]
#    --------------------------------- ------ 5/6 [sentence-transformers]
#    --------------------------------- ------ 5/6 [sentence-transformers]
#    --------------------------------- ------ 5/6 [sentence-transformers]
#    --------------------------------- ------ 5/6 [sentence-transformers]
#    --------------------------------- ------ 5/6 [sentence-transformers]
#    ---------------------------------------- 6/6 [sentence-transformers]
#
# Successfully installed huggingface-hub-0.36.0 safetensors-0.6.2 sentence-transformers-5.1.2 tokenizers-0.22.1 torch-2.9.0 transformers-4.57.1

# %%
import os
import sys
import array
import time
import oracledb
from sentence_transformers import SentenceTransformer

un = os.getenv("user", "TESTDB")
pw = os.getenv("password", "?renoma1")
cs = os.getenv("connstr", "localhost:1521/FREEPDB1")


#from langchain_community.embeddings import GPT4AllEmbeddings

embedding_model = "sentence-transformers/all-MiniLM-L6-v2"
model = SentenceTransformer(embedding_model, local_files_only=True)
#model = SentenceTransformer("jhgan/ko-sroberta-multitask")
#model = SentenceTransformer("intfloat/multilingual-e5-large")



query_sql = """SELECT id, info
                 FROM my_data
               ORDER BY 1"""
update_sql = """UPDATE my_data
                   SET v = :1
                 WHERE id = :2"""

# Connect to Oracle Database
with oracledb.connect(user=un, password=pw, dsn=cs) as connection:
    db_version = tuple(int(s) for s in connection.version.split("."))[:2]
    if db_version < (23, 4):
        sys.exit("The example requires Oracle Database 23.4 or later")
    print("Connected to Oracle Databse\n")

    with connection.cursor() as cursor:
        print("Vectorizing the following data:\n")

        # Loop over th rows and vectorize the VARCHAR2 data

        binds = []
        tic = time.perf_counter()
        #gpt4all_embd = GPT4AllEmbeddings()

        for id_val, info in cursor.execute(query_sql):
            # Convert to input string format for Sentence Transformers
            data = f"[ {info} ]"

            # Creating the embedding and extract the vector
            embedding = list(model.encode(data))
            #embedding = list(gpt4all_embd.embed_documents(data))
            

            # Convert to array format
            vec2 = array.array("f", embedding)

            # Record the array and key
            binds.append([vec2, id_val])

            print(info)

        toc = time.perf_counter()

        # Do an update to add or replace the vector values
        cursor.executemany(
            update_sql,
            binds,
        )
        connection.commit()

        print(f"Vectors took {toc - tic:0.3f} seconds")
        print(f"\nAdded {len(binds)} vectors to the table using embedding model: " + embedding_model + "\n")
# Out:
# Connected to Oracle Databse
#
# Vectorizing the following data:
#
# San Francisco is in California.
# San Jose is in California.
# Los Angeles is in California.
# Buffalo is in New York.
# Brooklyn is in New York.
# Queens is in New York.
# Harlem is in New York.
# The Bronx is in New York.
# Manhattan is in New York.
# Staten Island is in New York.
# Miami is in Florida.
# Tampa is in Florida.
# Orlando is in Florida.
# Dallas is in Texas.
# Houston is in Texas.
# Austin is in Texas.
# Phoenix is in Arizona.
# Las Vegas is in Nevada.
# Portland is in Oregon.
# New Orleans is in Louisiana.
# Atlanta is in Georgia.
# Chicago is in Illinois.
# Cleveland is in Ohio.
# Boston is in Massachusetts.
# Baltimore is in Maryland.
# Charlotte is in North Carolina.
# Raleigh is in North Carolina.
# Detroit is in Michigan.
# Ferraris are often red.
# Teslas are electric.
# Mini Coopers are small.
# Fiat 500 are small.
# Dodge Vipers are wide.
# Ford 150 are popular.
# Alfa Romeos are fun.
# Volvos are safe.
# Toyotas are reliable.
# Hondas are reliable.
# Porsches are fast and reliable.
# Nissan GTR are great.
# NISMO is awesome.
# Tesla Cybertrucks are big.
# Jeep Wranglers are fun.
# Lamborghinis are fast.
# Bananas are yellow.
# Kiwis are green inside.
# Kiwis are brown on the outside.
# Kiwis are birds.
# Kiwis taste good.
# Ripe strawberries are red.
# Apples can be green, yellow or red.
# Ripe cherries are red.
# Pears can be green, yellow or brown.
# Oranges are orange.
# Peaches can be yellow, orange or red.
# Peaches can be fuzzy.
# Grapes can be green, red or puple.
# Watermelons are green on the outside.
# Watermelons are red on the inside.
# Blueberries are blue.
# Limes are green.
# Lemons are yellow.
# Ripe tomatoes are red.
# Unripe tomatoes are green.
# Ripe raspberries are red.
# Mangoes can be yellow, gold, green or orange.
# Tigers have stripes.
# Lions are big.
# Mice are small.
# Cats do not care.
# Dogs are loyal.
# Bears are hairy.
# Pandas are black and white.
# Zebras are black and white.
# Penguins can be black and white.
# Puffins can be black and white.
# Giraffes have long necks.
# Elephants have trunks.
# Horses have four legs.
# Birds can fly.
# Birds lay eggs.
# Fish can swim.
# Sharks have lots of teeth.
# Flies can fly.
# Snakes have fangs.
# Hyenas laugh.
# Crocodiles lurk.
# Spiders have eight legs.
# Wolves are hairy.
# Mountain Lions eat deer.
# Kangaroos can hop.
# Turtles have shells.
# Ibaraki is in Kanto.
# Tochigi is in Kanto.
# Gunma is in Kanto.
# Saitama is in Kanto.
# Chiba is in Kanto.
# Tokyo is in Kanto.
# Kanagawa is in Kanto.
# Eggs are egg shaped.
# Sydney is in Australia.
# To be, or not to be, taht is the question.
# 640K ought to be enough for anybody.
# Man overboard.
# The world is your oyster.
# One small step for Mankind.
# Bitcoin is a cryptocurrency.
# Saturn has rings.
# Antarctica is very cold.
# Wellington is the capital of New Zealand.
# The Amazon River is the largest river by discharge.
# Catamarans have two hulls.
# Monohulls have a single hull.
# Foiling sailboats are fast.
# Cutters have two headsails.
# Yawls have two masts.
# Sloops have one mast.
# HMS Endeavour was a squared rigged ship.
# Auckland has hosted the Americas Cup race three times.
# Joshua Slocum sailed the first solo circumnavigation of the world.
# Oracle CloudWorld Las Vegas was on September 18–21, 2023
# Oracle CloudWorld Las Vegas was at The Venetian Convention and Expo Center
# Oracle CloudWorld Dubai was on 23 January 2024
# Oracle CloudWorld Dubai is at the Dubai World Trade Centre
# Oracle CloudWorld Mumbai was on 14 February 2024
# Oracle CloudWorld Mumbai is at the Jio World Convention Centre
# Oracle CloudWorld London was on 14 March 2024
# Oracle CloudWorld London is at the ExCeL London
# Oracle CloudWorld Milan was on 21 March 2024
# Oracle CloudWorld Milan is at the Milano Convention Centre
# Oracle CloudWorld Sao Paulo was on 4 April 2024
# Oracle CloudWorld Sao Paulo is at the World Trade Center São Paulo
# Oracle CloudWorld Singapore is on 16 April 2024
# Oracle CloudWorld Tokyo is on 18 April 2024
# Oracle CloudWorld Tokyo is at The Prince Park Tower Tokyo
# Oracle CloudWorld Mexico City is on 25 April 2024
# Oracle CloudWorld Mexico City is at the Centro Citibanamex
# Mumbai is in India.
# Mumbai is the capital city of the Indian state of Maharashtra.
# Mumbai is the Indian state of Maharashtra.
# Mumbai is on the west coast of India.
# Mumbai is the de facto financial centre of India.
# Mumbai has a population of about 12.5 million people.
# Mumbai is hot with an average minimum temperature of 24 degrees celsius.
# Common languages in Mumbai are Marathi, Hindi, Gujarati, Urdu, Bambaiya and English.
# Dubai is in the United Arab Emirates.
# The Burj Khalifa is in Dubai.
# The Burj Khalifa is tallest building in the world.
# Dubai is in the Persian Gulf.
# The United Arab Emirates consists of seven emirates.
# Vectors took 1.341 seconds
#
# Added 150 vectors to the table using embedding model: sentence-transformers/all-MiniLM-L6-v2

# %% [raw]
# 4. Perform Similarity Search with Sentence Transformers

# %%
import os
import sys
import array
import time
import oracledb

from sentence_transformers import SentenceTransformer
from sentence_transformers import CrossEncoder

un = os.getenv("user", "TESTDB")
pw = os.getenv("password", "?renoma1")
cs = os.getenv("connstr", "localhost:1521/FREEPDB1")

# topK is how many rows to return
topK = 5

# Re-ranking is about potentially improving the order of the resultset
# Re-ranking is significantly slower than doing similarity search
# Re-ranking is optional
rerank = 0

sql = """SELECT info
           FROM my_data
         ORDER BY VECTOR_DISTANCE(v, :1, COSINE)
         FETCH FIRST :2 ROWS ONLY"""

#sql = """select info 
#         from my_data 
#         order by vector_distance(v, :1, COSINE) 
#         fetch first :2 rows only"""

embedding_model = "sentence-transformers/all-MiniLM-L6-v2"

# English re-rankers
rerank_model = "cross-encoder/ms-macro-TinyBERT-L-2-v2"

print("Using embedding model " + embedding_model)
if rerank:
    print("Using reranker " + rerank_model)

print("TopK = " + str(topK))

model = SentenceTransformer(embedding_model, local_files_only=True, trust_remote_code=False)

# Connect to Oracle Database
with oracledb.connect(user=un, password=pw, dsn=cs) as connection:
    db_version = tuple(int(s) for s in connection.version.split("."))[:2]
    if db_version < (23, 4):
        sys.exit("This example requires Oracle Database 23.4 or later")
    print("Connected to Oracle Database\n")

    with connection.cursor() as cursor:

        while True:
        
            # Get the input trext to vectorize
            text = input("\nEnter a phrase. Type quit to exit :")
    
            if (text == "quit") or (text == "exit"):
                break

            if text == "":
                continue
    
            tic = time.perf_counter()
    
            # Create the embedding and extract the vector
            embedding = list(model.encode(text))
            
            #print("!!!! -> " + str(embedding))
    
            toc = time.perf_counter()
            print(f"\nVectorize query took {toc - tic:0.3f} seconds")
    
            # Convert to array format
            vec = array.array("f", embedding)
    
            docs = []
            cross = []
    
            tic = time.perf_counter()
    
            # Do the similarity Search
            for (info,) in cursor.execute(sql, [vec, topK]): 
                # Remember the SQL data resultset
                docs.append(info)
    
                if rerank == 1:
                    # create the query/data pair needed for cross encoding
                    tup = []
                    tup.append(text)
                    tup.append(info)
                    cross.append(tup)
    
            toc = time.perf_counter()
            print(f"Similarity Search took {toc - tic:0.4f} seconds")
    
            if rerank == 0:
                # Just rely on the vector distance for the resultset order
                print("\nWithout ReRanking")
                print("====================================")
                for hit in docs:
                    print(hit)
    
            else:
                tic = time.perf_counter()
    
                #ReRank for better results
                ce = CrossEncoder(rerank_model, max_length=512)
                ce_scores = ce.predict(cross)
    
                toc = time.perf_counter()
                print(f"Rerank took {toc - tic:0.3f} seconds")
    
                # Create the unranked list of ce_scores + data
                unranked = []
                for idx in range(topK):
                    tup2 = []
                    tup2.append(ce_scores[idx])
                    tup2.append(docs[idx])
                    unranked.append(tup2)
    
                # Create the reranked list by sorting the unranked list
                reranked = sorted(unranked, key=lambda foo: foo[0], reverse=True)
    
                print("\nReRanked result:")
                print("====================================")
                for idx in range(topK):
                    x = reranked[idx]
                    print(x[1])
    
                print("------------------------------------")
# Out:
# Using embedding model sentence-transformers/all-MiniLM-L6-v2
# TopK = 5
# Connected to Oracle Database
# Enter a phrase. Type quit to exit : cars
# Vectorize query took 0.012 seconds
# Similarity Search took 0.0033 seconds
#
# Without ReRanking
# ====================================
# Porsches are fast and reliable.
# Nissan GTR are great.
# Toyotas are reliable.
# Alfa Romeos are fun.
# Ford 150 are popular.
# Enter a phrase. Type quit to exit : person
# Vectorize query took 0.011 seconds
# Similarity Search took 0.0028 seconds
#
# Without ReRanking
# ====================================
# Man overboard.
# The Burj Khalifa is tallest building in the world.
# One small step for Mankind.
# Bitcoin is a cryptocurrency.
# To be, or not to be, taht is the question.
# Enter a phrase. Type quit to exit : food
# Vectorize query took 0.011 seconds
# Similarity Search took 0.0016 seconds
#
# Without ReRanking
# ====================================
# Watermelons are red on the inside.
# Mountain Lions eat deer.
# Kiwis taste good.
# Watermelons are green on the outside.
# Birds lay eggs.
# Enter a phrase. Type quit to exit : yellow food
# Vectorize query took 0.010 seconds
# Similarity Search took 0.0016 seconds
#
# Without ReRanking
# ====================================
# Bananas are yellow.
# Lemons are yellow.
# Mangoes can be yellow, gold, green or orange.
# Kiwis are green inside.
# Ripe tomatoes are red.
# Enter a phrase. Type quit to exit : boroughs
# Vectorize query took 0.009 seconds
# Similarity Search took 0.0021 seconds
#
# Without ReRanking
# ====================================
# The Bronx is in New York.
# Brooklyn is in New York.
# Staten Island is in New York.
# Manhattan is in New York.
# Queens is in New York.
# Enter a phrase. Type quit to exit : New Zealand
# Vectorize query took 0.012 seconds
# Similarity Search took 0.0029 seconds
#
# Without ReRanking
# ====================================
# Wellington is the capital of New Zealand.
# Auckland has hosted the Americas Cup race three times.
# Staten Island is in New York.
# Sydney is in Australia.
# Harlem is in New York.
# Enter a phrase. Type quit to exit : quit

# %% [raw]
# ======================================================================================================

# %%
pip install -U langchain
# Out:
# Collecting langchain
#   Downloading langchain-1.0.3-py3-none-any.whl.metadata (4.7 kB)
# Collecting langchain-core<2.0.0,>=1.0.0 (from langchain)
#   Downloading langchain_core-1.0.3-py3-none-any.whl.metadata (3.5 kB)
# Collecting langgraph<1.1.0,>=1.0.2 (from langchain)
#   Downloading langgraph-1.0.2-py3-none-any.whl.metadata (7.4 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\77100643\anaconda3\lib\site-packages (from langchain) (2.10.3)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\77100643\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain) (1.33)
# Collecting langsmith<1.0.0,>=0.3.45 (from langchain-core<2.0.0,>=1.0.0->langchain)
#   Downloading langsmith-0.4.40-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\77100643\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain) (24.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\77100643\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain) (6.0.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\77100643\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain) (9.0.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\77100643\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain) (4.15.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\77100643\anaconda3\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.0->langchain) (2.1)
# Collecting langgraph-checkpoint<4.0.0,>=2.1.0 (from langgraph<1.1.0,>=1.0.2->langchain)
#   Downloading langgraph_checkpoint-3.0.0-py3-none-any.whl.metadata (4.2 kB)
# Collecting langgraph-prebuilt<1.1.0,>=1.0.2 (from langgraph<1.1.0,>=1.0.2->langchain)
#   Downloading langgraph_prebuilt-1.0.2-py3-none-any.whl.metadata (5.0 kB)
# Collecting langgraph-sdk<0.3.0,>=0.2.2 (from langgraph<1.1.0,>=1.0.2->langchain)
#   Downloading langgraph_sdk-0.2.9-py3-none-any.whl.metadata (1.5 kB)
# Collecting xxhash>=3.5.0 (from langgraph<1.1.0,>=1.0.2->langchain)
#   Downloading xxhash-3.6.0-cp313-cp313-win_amd64.whl.metadata (13 kB)
# Collecting ormsgpack>=1.10.0 (from langgraph-checkpoint<4.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.2->langchain)
#   Downloading ormsgpack-1.11.0-cp313-cp313-win_amd64.whl.metadata (1.2 kB)
# Requirement already satisfied: httpx>=0.25.2 in c:\users\77100643\anaconda3\lib\site-packages (from langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (0.28.1)
# Collecting orjson>=3.10.1 (from langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain)
#   Downloading orjson-3.11.4-cp313-cp313-win_amd64.whl.metadata (42 kB)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\77100643\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\77100643\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain) (2.32.3)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\77100643\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain) (0.23.0)
# Requirement already satisfied: anyio in c:\users\77100643\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (4.7.0)
# Requirement already satisfied: certifi in c:\users\77100643\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in c:\users\77100643\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (1.0.9)
# Requirement already satisfied: idna in c:\users\77100643\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (3.7)
# Requirement already satisfied: h11>=0.16 in c:\users\77100643\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\77100643\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in c:\users\77100643\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.27.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\77100643\anaconda3\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\77100643\anaconda3\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain) (2.3.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\77100643\anaconda3\lib\site-packages (from anyio->httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (1.3.0)
# Downloading langchain-1.0.3-py3-none-any.whl (91 kB)
# Downloading langchain_core-1.0.3-py3-none-any.whl (469 kB)
# Downloading langgraph-1.0.2-py3-none-any.whl (156 kB)
# Downloading langgraph_checkpoint-3.0.0-py3-none-any.whl (46 kB)
# Downloading langgraph_prebuilt-1.0.2-py3-none-any.whl (34 kB)
# Downloading langgraph_sdk-0.2.9-py3-none-any.whl (56 kB)
# Downloading langsmith-0.4.40-py3-none-any.whl (399 kB)
# Downloading orjson-3.11.4-cp313-cp313-win_amd64.whl (131 kB)
# Downloading ormsgpack-1.11.0-cp313-cp313-win_amd64.whl (112 kB)
# Downloading xxhash-3.6.0-cp313-cp313-win_amd64.whl (31 kB)
# Installing collected packages: xxhash, ormsgpack, orjson, langsmith, langgraph-sdk, langchain-core, langgraph-checkpoint, langgraph-prebuilt, langgraph, langchain
#
#    ------------ ---------------------------  3/10 [langsmith]
#    ------------ ---------------------------  3/10 [langsmith]
#    ------------ ---------------------------  3/10 [langsmith]
#    ------------ ---------------------------  3/10 [langsmith]
#    ---------------- -----------------------  4/10 [langgraph-sdk]
#    -------------------- -------------------  5/10 [langchain-core]
#    -------------------- -------------------  5/10 [langchain-core]
#    -------------------- -------------------  5/10 [langchain-core]
#    -------------------- -------------------  5/10 [langchain-core]
#    -------------------- -------------------  5/10 [langchain-core]
#    -------------------- -------------------  5/10 [langchain-core]
#    -------------------- -------------------  5/10 [langchain-core]
#    -------------------- -------------------  5/10 [langchain-core]
#    -------------------- -------------------  5/10 [langchain-core]
#    ------------------------ ---------------  6/10 [langgraph-checkpoint]
#    -------------------------------- -------  8/10 [langgraph]
#    -------------------------------- -------  8/10 [langgraph]
#    -------------------------------- -------  8/10 [langgraph]
#    ------------------------------------ ---  9/10 [langchain]
#    ------------------------------------ ---  9/10 [langchain]
#    ---------------------------------------- 10/10 [langchain]
#
# Successfully installed langchain-1.0.3 langchain-core-1.0.3 langgraph-1.0.2 langgraph-checkpoint-3.0.0 langgraph-prebuilt-1.0.2 langgraph-sdk-0.2.9 langsmith-0.4.40 orjson-3.11.4 ormsgpack-1.11.0 xxhash-3.6.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install -U langchain_community
# Out:
# Collecting langchain_community
#   Using cached langchain_community-0.4.1-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.1 in c:\users\77100643\anaconda3\lib\site-packages (from langchain_community) (1.0.3)
# Collecting langchain-classic<2.0.0,>=1.0.0 (from langchain_community)
#   Using cached langchain_classic-1.0.0-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in c:\users\77100643\anaconda3\lib\site-packages (from langchain_community) (2.0.39)
# Collecting requests<3.0.0,>=2.32.5 (from langchain_community)
#   Using cached requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in c:\users\77100643\anaconda3\lib\site-packages (from langchain_community) (6.0.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\77100643\anaconda3\lib\site-packages (from langchain_community) (3.11.10)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\77100643\anaconda3\lib\site-packages (from langchain_community) (9.0.0)
# Collecting dataclasses-json<0.7.0,>=0.6.7 (from langchain_community)
#   Using cached dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting pydantic-settings<3.0.0,>=2.10.1 (from langchain_community)
#   Using cached pydantic_settings-2.11.0-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in c:\users\77100643\anaconda3\lib\site-packages (from langchain_community) (0.4.40)
# Collecting httpx-sse<1.0.0,>=0.4.0 (from langchain_community)
#   Downloading httpx_sse-0.4.3-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: numpy>=2.1.0 in c:\users\77100643\anaconda3\lib\site-packages (from langchain_community) (2.1.3)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\77100643\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\77100643\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\77100643\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\77100643\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\77100643\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\77100643\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\77100643\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.18.0)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7.0,>=0.6.7->langchain_community)
#   Using cached marshmallow-3.26.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7.0,>=0.6.7->langchain_community)
#   Using cached typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting langchain-text-splitters<2.0.0,>=1.0.0 (from langchain-classic<2.0.0,>=1.0.0->langchain_community)
#   Using cached langchain_text_splitters-1.0.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\77100643\anaconda3\lib\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain_community) (2.10.3)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\77100643\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.0.1->langchain_community) (1.33)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\77100643\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.0.1->langchain_community) (24.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\77100643\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.0.1->langchain_community) (4.15.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\77100643\anaconda3\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.1->langchain_community) (2.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\77100643\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\77100643\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (3.11.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\77100643\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\77100643\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (0.23.0)
# Requirement already satisfied: anyio in c:\users\77100643\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (4.7.0)
# Requirement already satisfied: certifi in c:\users\77100643\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in c:\users\77100643\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (1.0.9)
# Requirement already satisfied: idna in c:\users\77100643\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (3.7)
# Requirement already satisfied: h11>=0.16 in c:\users\77100643\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\77100643\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain_community) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in c:\users\77100643\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain_community) (2.27.1)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\77100643\anaconda3\lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain_community) (1.1.0)
# Collecting typing-inspection>=0.4.0 (from pydantic-settings<3.0.0,>=2.10.1->langchain_community)
#   Using cached typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\77100643\anaconda3\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain_community) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\77100643\anaconda3\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain_community) (2.3.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\77100643\anaconda3\lib\site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain_community) (3.1.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\77100643\anaconda3\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain_community) (1.0.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\77100643\anaconda3\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (1.3.0)
# Using cached langchain_community-0.4.1-py3-none-any.whl (2.5 MB)
# Using cached dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading httpx_sse-0.4.3-py3-none-any.whl (9.0 kB)
# Using cached langchain_classic-1.0.0-py3-none-any.whl (1.0 MB)
# Using cached langchain_text_splitters-1.0.0-py3-none-any.whl (33 kB)
# Using cached marshmallow-3.26.1-py3-none-any.whl (50 kB)
# Using cached pydantic_settings-2.11.0-py3-none-any.whl (48 kB)
# Using cached requests-2.32.5-py3-none-any.whl (64 kB)
# Using cached typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Using cached typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Installing collected packages: typing-inspection, typing-inspect, requests, marshmallow, httpx-sse, dataclasses-json, pydantic-settings, langchain-text-splitters, langchain-classic, langchain_community
#
#   Attempting uninstall: requests
#
#     Found existing installation: requests 2.32.3
#
#     Uninstalling requests-2.32.3:
#
#       Successfully uninstalled requests-2.32.3
#
#    -------- -------------------------------  2/10 [requests]
#    -------- -------------------------------  2/10 [requests]
#    ---------------- -----------------------  4/10 [httpx-sse]
#   Attempting uninstall: pydantic-settings
#    ---------------- -----------------------  4/10 [httpx-sse]
#     Found existing installation: pydantic-settings 2.6.1
#    ---------------- -----------------------  4/10 [httpx-sse]
#     Uninstalling pydantic-settings-2.6.1:
#    ---------------- -----------------------  4/10 [httpx-sse]
#       Successfully uninstalled pydantic-settings-2.6.1
#    ---------------- -----------------------  4/10 [httpx-sse]
#    ------------------------ ---------------  6/10 [pydantic-settings]
#    ------------------------ ---------------  6/10 [pydantic-settings]
#    -------------------------------- -------  8/10 [langchain-classic]
#    -------------------------------- -------  8/10 [langchain-classic]
#    -------------------------------- -------  8/10 [langchain-classic]
#    -------------------------------- -------  8/10 [langchain-classic]
#    -------------------------------- -------  8/10 [langchain-classic]
#    -------------------------------- -------  8/10 [langchain-classic]
#    -------------------------------- -------  8/10 [langchain-classic]
#    -------------------------------- -------  8/10 [langchain-classic]
#    -------------------------------- -------  8/10 [langchain-classic]
#    -------------------------------- -------  8/10 [langchain-classic]
#    -------------------------------- -------  8/10 [langchain-classic]
#    -------------------------------- -------  8/10 [langchain-classic]
#    -------------------------------- -------  8/10 [langchain-classic]
#    -------------------------------- -------  8/10 [langchain-classic]
#    -------------------------------- -------  8/10 [langchain-classic]
#    -------------------------------- -------  8/10 [langchain-classic]
#    -------------------------------- -------  8/10 [langchain-classic]
#    -------------------------------- -------  8/10 [langchain-classic]
#    -------------------------------- -------  8/10 [langchain-classic]
#    -------------------------------- -------  8/10 [langchain-classic]
#    -------------------------------- -------  8/10 [langchain-classic]
#    -------------------------------- -------  8/10 [langchain-classic]
#    -------------------------------- -------  8/10 [langchain-classic]
#    -------------------------------- -------  8/10 [langchain-classic]
#    -------------------------------- -------  8/10 [langchain-classic]
#    -------------------------------- -------  8/10 [langchain-classic]
#    -------------------------------- -------  8/10 [langchain-classic]
#    -------------------------------- -------  8/10 [langchain-classic]
#    -------------------------------- -------  8/10 [langchain-classic]
#    -------------------------------- -------  8/10 [langchain-classic]
#    -------------------------------- -------  8/10 [langchain-classic]
#    -------------------------------- -------  8/10 [langchain-classic]
#    -------------------------------- -------  8/10 [langchain-classic]
#    -------------------------------- -------  8/10 [langchain-classic]
#    -------------------------------- -------  8/10 [langchain-classic]
#    -------------------------------- -------  8/10 [langchain-classic]
#    -------------------------------- -------  8/10 [langchain-classic]
#    -------------------------------- -------  8/10 [langchain-classic]
#    -------------------------------- -------  8/10 [langchain-classic]
#    -------------------------------- -------  8/10 [langchain-classic]
#    -------------------------------- -------  8/10 [langchain-classic]
#    -------------------------------- -------  8/10 [langchain-classic]
#    -------------------------------- -------  8/10 [langchain-classic]
#    -------------------------------- -------  8/10 [langchain-classic]
#    -------------------------------- -------  8/10 [langchain-classic]
#    -------------------------------- -------  8/10 [langchain-classic]
#    -------------------------------- -------  8/10 [langchain-classic]
#    -------------------------------- -------  8/10 [langchain-classic]
#    -------------------------------- -------  8/10 [langchain-classic]
#    -------------------------------- -------  8/10 [langchain-classic]
#    -------------------------------- -------  8/10 [langchain-classic]
#    -------------------------------- -------  8/10 [langchain-classic]
#    -------------------------------- -------  8/10 [langchain-classic]
#    -------------------------------- -------  8/10 [langchain-classic]
#    -------------------------------- -------  8/10 [langchain-classic]
#    -------------------------------- -------  8/10 [langchain-classic]
#    ------------------------------------ ---  9/10 [langchain_community]
#    ------------------------------------ ---  9/10 [langchain_community]
#    ------------------------------------ ---  9/10 [langchain_community]
#    ------------------------------------ ---  9/10 [langchain_community]
#    ------------------------------------ ---  9/10 [langchain_community]
#    ------------------------------------ ---  9/10 [langchain_community]
#    ------------------------------------ ---  9/10 [langchain_community]
#    ------------------------------------ ---  9/10 [langchain_community]
#    ------------------------------------ ---  9/10 [langchain_community]
#    ------------------------------------ ---  9/10 [langchain_community]
#    ------------------------------------ ---  9/10 [langchain_community]
#    ------------------------------------ ---  9/10 [langchain_community]
#    ------------------------------------ ---  9/10 [langchain_community]
#    ------------------------------------ ---  9/10 [langchain_community]
#    ------------------------------------ ---  9/10 [langchain_community]
#    ------------------------------------ ---  9/10 [langchain_community]
#    ------------------------------------ ---  9/10 [langchain_community]
#    ------------------------------------ ---  9/10 [langchain_community]
#    ------------------------------------ ---  9/10 [langchain_community]
#    ------------------------------------ ---  9/10 [langchain_community]
#    ------------------------------------ ---  9/10 [langchain_community]
#    ------------------------------------ ---  9/10 [langchain_community]
#    ------------------------------------ ---  9/10 [langchain_community]
#    ------------------------------------ ---  9/10 [langchain_community]
#    ------------------------------------ ---  9/10 [langchain_community]
#    ------------------------------------ ---  9/10 [langchain_community]
#    ------------------------------------ ---  9/10 [langchain_community]
#    ------------------------------------ ---  9/10 [langchain_community]
#    ------------------------------------ ---  9/10 [langchain_community]
#    ------------------------------------ ---  9/10 [langchain_community]
#    ------------------------------------ ---  9/10 [langchain_community]
#    ------------------------------------ ---  9/10 [langchain_community]
#    ------------------------------------ ---  9/10 [langchain_community]
#    ------------------------------------ ---  9/10 [langchain_community]
#    ------------------------------------ ---  9/10 [langchain_community]
#    ------------------------------------ ---  9/10 [langchain_community]
#    ------------------------------------ ---  9/10 [langchain_community]
#    ------------------------------------ ---  9/10 [langchain_community]
#    ------------------------------------ ---  9/10 [langchain_community]
#    ------------------------------------ ---  9/10 [langchain_community]
#    ------------------------------------ ---  9/10 [langchain_community]
#    ------------------------------------ ---  9/10 [langchain_community]
#    ------------------------------------ ---  9/10 [langchain_community]
#    ------------------------------------ ---  9/10 [langchain_community]
#    ------------------------------------ ---  9/10 [langchain_community]
#    ------------------------------------ ---  9/10 [langchain_community]
#    ------------------------------------ ---  9/10 [langchain_community]
#    ------------------------------------ ---  9/10 [langchain_community]
#    ------------------------------------ ---  9/10 [langchain_community]
#    ------------------------------------ ---  9/10 [langchain_community]
#    ------------------------------------ ---  9/10 [langchain_community]
#    ------------------------------------ ---  9/10 [langchain_community]
#    ------------------------------------ ---  9/10 [langchain_community]
#    ------------------------------------ ---  9/10 [langchain_community]
#    ------------------------------------ ---  9/10 [langchain_community]
#    ------------------------------------ ---  9/10 [langchain_community]
#    ------------------------------------ ---  9/10 [langchain_community]
#    ------------------------------------ ---  9/10 [langchain_community]
#    ------------------------------------ ---  9/10 [langchain_community]
#    ------------------------------------ ---  9/10 [langchain_community]
#    ------------------------------------ ---  9/10 [langchain_community]
#    ------------------------------------ ---  9/10 [langchain_community]
#    ------------------------------------ ---  9/10 [langchain_community]
#    ------------------------------------ ---  9/10 [langchain_community]
#    ------------------------------------ ---  9/10 [langchain_community]
#    ------------------------------------ ---  9/10 [langchain_community]
#    ------------------------------------ ---  9/10 [langchain_community]
#    ------------------------------------ ---  9/10 [langchain_community]
#    ------------------------------------ ---  9/10 [langchain_community]
#    ------------------------------------ ---  9/10 [langchain_community]
#    ------------------------------------ ---  9/10 [langchain_community]
#    ------------------------------------ ---  9/10 [langchain_community]
#    ------------------------------------ ---  9/10 [langchain_community]
#    ------------------------------------ ---  9/10 [langchain_community]
#    ------------------------------------ ---  9/10 [langchain_community]
#    ------------------------------------ ---  9/10 [langchain_community]
#    ------------------------------------ ---  9/10 [langchain_community]
#    ------------------------------------ ---  9/10 [langchain_community]
#    ---------------------------------------- 10/10 [langchain_community]
#
# Successfully installed dataclasses-json-0.6.7 httpx-sse-0.4.3 langchain-classic-1.0.0 langchain-text-splitters-1.0.0 langchain_community-0.4.1 marshmallow-3.26.1 pydantic-settings-2.11.0 requests-2.32.5 typing-inspect-0.9.0 typing-inspection-0.4.2
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install GPT4All
# Out:
# Collecting GPT4All
#   Downloading gpt4all-2.8.2-py3-none-win_amd64.whl.metadata (4.8 kB)
# Requirement already satisfied: requests in c:\users\77100643\anaconda3\lib\site-packages (from GPT4All) (2.32.3)
# Requirement already satisfied: tqdm in c:\users\77100643\anaconda3\lib\site-packages (from GPT4All) (4.67.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\77100643\anaconda3\lib\site-packages (from requests->GPT4All) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\77100643\anaconda3\lib\site-packages (from requests->GPT4All) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\77100643\anaconda3\lib\site-packages (from requests->GPT4All) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\77100643\anaconda3\lib\site-packages (from requests->GPT4All) (2025.10.5)
# Requirement already satisfied: colorama in c:\users\77100643\anaconda3\lib\site-packages (from tqdm->GPT4All) (0.4.6)
# Downloading gpt4all-2.8.2-py3-none-win_amd64.whl (119.6 MB)
#    ---------------------------------------- 0.0/119.6 MB ? eta -:--:--
#     --------------------------------------- 1.6/119.6 MB 7.1 MB/s eta 0:00:17
#     --------------------------------------- 2.4/119.6 MB 5.9 MB/s eta 0:00:21
#    - -------------------------------------- 3.9/119.6 MB 6.5 MB/s eta 0:00:18
#    - -------------------------------------- 5.0/119.6 MB 6.3 MB/s eta 0:00:19
#    -- ------------------------------------- 6.3/119.6 MB 6.1 MB/s eta 0:00:19
#    -- ------------------------------------- 8.1/119.6 MB 6.6 MB/s eta 0:00:17
#    --- ------------------------------------ 10.0/119.6 MB 6.9 MB/s eta 0:00:16
#    --- ------------------------------------ 11.5/119.6 MB 7.0 MB/s eta 0:00:16
#    ---- ----------------------------------- 12.6/119.6 MB 6.8 MB/s eta 0:00:16
#    ---- ----------------------------------- 14.2/119.6 MB 6.9 MB/s eta 0:00:16
#    ----- ---------------------------------- 16.3/119.6 MB 7.1 MB/s eta 0:00:15
#    ----- ---------------------------------- 17.8/119.6 MB 7.3 MB/s eta 0:00:15
#    ------ --------------------------------- 19.9/119.6 MB 7.4 MB/s eta 0:00:14
#    ------- -------------------------------- 21.5/119.6 MB 7.4 MB/s eta 0:00:14
#    ------- -------------------------------- 23.3/119.6 MB 7.5 MB/s eta 0:00:13
#    -------- ------------------------------- 24.9/119.6 MB 7.6 MB/s eta 0:00:13
#    -------- ------------------------------- 26.2/119.6 MB 7.5 MB/s eta 0:00:13
#    --------- ------------------------------ 27.0/119.6 MB 7.3 MB/s eta 0:00:13
#    --------- ------------------------------ 28.6/119.6 MB 7.3 MB/s eta 0:00:13
#    ---------- ----------------------------- 30.4/119.6 MB 7.4 MB/s eta 0:00:13
#    ---------- ----------------------------- 31.5/119.6 MB 7.3 MB/s eta 0:00:13
#    ---------- ----------------------------- 32.5/119.6 MB 7.2 MB/s eta 0:00:13
#    ----------- ---------------------------- 34.3/119.6 MB 7.2 MB/s eta 0:00:12
#    ------------ --------------------------- 35.9/119.6 MB 7.3 MB/s eta 0:00:12
#    ------------ --------------------------- 37.7/119.6 MB 7.3 MB/s eta 0:00:12
#    ------------- -------------------------- 39.6/119.6 MB 7.4 MB/s eta 0:00:11
#    ------------- -------------------------- 41.2/119.6 MB 7.4 MB/s eta 0:00:11
#    -------------- ------------------------- 43.0/119.6 MB 7.4 MB/s eta 0:00:11
#    -------------- ------------------------- 44.6/119.6 MB 7.5 MB/s eta 0:00:11
#    --------------- ------------------------ 46.4/119.6 MB 7.5 MB/s eta 0:00:10
#    ---------------- ----------------------- 48.2/119.6 MB 7.6 MB/s eta 0:00:10
#    ---------------- ----------------------- 49.5/119.6 MB 7.5 MB/s eta 0:00:10
#    ---------------- ----------------------- 50.3/119.6 MB 7.4 MB/s eta 0:00:10
#    ----------------- ---------------------- 51.1/119.6 MB 7.3 MB/s eta 0:00:10
#    ----------------- ----------------------